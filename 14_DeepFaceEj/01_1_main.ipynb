# %%
#!pip install tf-keras

# %%
#!pip install deepface

# %%
from deepface import DeepFace

# %%
result = DeepFace.verify(
    img1_path = "Angelina_Jolie/AngelinaJolie1.jpg",
    img2_path = "Angelina_Jolie/AngelinaJolie2.jpg",
)
result
# Out:
# {'verified': True,
#  'distance': 0.42751995215688965,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 1.33}

# %%
img1_path = "Angelina_Jolie/AngelinaJolie1.jpg"
img2_path = "Angelina_Jolie/AngelinaJolie2.jpg"

DeepFace.verify(img1_path, img2_path, model_name="Facenet")
# Out:
# {'verified': True,
#  'distance': 0.23027367852471214,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 1.88}

# %%
#DeepFace.verify?

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img1_path = "Angelina_Jolie/AngelinaJolie1.jpg"
img2_path = "Angelina_Jolie/AngelinaJolie2.jpg"

# %%
img1 = plt.imread(img1_path)
img2 = plt.imread(img2_path)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img1)
plt.subplot(1, 2, 2)
plt.imshow(img2)
img1.shape, img2.shape
# Out:
# ((1080, 1920, 3), (1604, 1200, 3))

# %%
img1_faces = DeepFace.extract_faces(img1_path)
img2_faces = DeepFace.extract_faces(img2_path)

img1 = img1_faces[0]["face"]
img2 = img2_faces[0]["face"]
print(img1.shape)

fig = plt.figure(figsize=(10,5))
fig.add_subplot(1,2,1)
plt.imshow(img1)
fig.add_subplot(1,2,2)
plt.imshow(img2)
# Out:
# (505, 505, 3)

# %%
img1 = img1_faces[0]["face"]
img2 = img1_faces[1]["face"]


fig = plt.figure(figsize=(10,5))
fig.add_subplot(1,2,1)
plt.imshow(img1)
fig.add_subplot(1,2,2)
plt.imshow(img2)

# %%
model_name = "VGG-Face"
resp = DeepFace.verify(img1_path, img2_path, model_name = model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.42751995215688965,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 0.97}

# %%
model_name = "Facenet"
resp2 = DeepFace.verify(img1_path, img2_path, model_name = model_name)
resp2
# Out:
# {'verified': True,
#  'distance': 0.23027367852471214,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 0.95}

# %%
model_name = "GhostFaceNet"
resp2 = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp2
# Out:
# {'verified': True,
#  'distance': 0.405288953128245,
#  'threshold': 0.65,
#  'model': 'GhostFaceNet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 2.03}

# %%
model_name = "Facenet512"
resp2 = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp2
# Out:
# {'verified': True,
#  'distance': 0.23727229354537505,
#  'threshold': 0.3,
#  'model': 'Facenet512',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 1.73}

# %%
#DeepFace.verify?
#info = DeepFace.verify.__doc__
#posi = info.find("Options:")
#posf = info[posi:].find(".")
#model_options = info[posi:posi+posf]
#print(model_options)

# %%
model_names = "VGG-Face, Facenet, Facenet512, OpenFace, DeepID, ArcFace, SFace, GhostFaceNet".split(", ")  
model_names
# Out:
# ['VGG-Face',
#  'Facenet',
#  'Facenet512',
#  'OpenFace',
#  'DeepID',
#  'ArcFace',
#  'SFace',
#  'GhostFaceNet']

# %%
for model_name in model_names:
    print(model_name)
    resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
    print(resp)
    print("-"*50)
# Out:
# VGG-Face
# {'verified': True, 'distance': 0.42751995215688965, 'threshold': 0.68, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 0.95}
# --------------------------------------------------
# Facenet
# {'verified': True, 'distance': 0.23027367852471214, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 0.88}
# --------------------------------------------------
# Facenet512
# ...

# %%
def graficar (img1,img2):
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.imshow(img1)
    fig.add_subplot(1,2,2)
    plt.imshow(img2)

# %%
folder_path = "Keira_Knightley"
img1_path = f"{folder_path}/img0.jpg"
img2_path = f"{folder_path}/img1.jpg"
#img2_path = f"{folder_path}/img2.jpg" #error Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
model_name = "Facenet"

img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)
graficar(img1[0]["face"],img2[0]["face"])

resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.34687379368031235,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 249,
#    'y': 230,
#    'w': 393,
#    'h': 393,
#    'left_eye': (516, 384),
#    'right_eye': (370, 381)},
#   'img2': {'x': 833,
#    'y': 328,
#    'w': 285,
#    'h': 285,
#    'left_eye': (1026, 433),
#    'right_eye': (913, 435)}},
#  'time': 1.44}

# %%
folder_path = "Natalie_Portman"
img1_path = f"{folder_path}/img0.jpg"
img2_path = f"{folder_path}/img2.jpg"
model_name = "Facenet"

img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)
graficar(img1[0]["face"],img2[0]["face"])

resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.33311015529007715,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 944,
#    'y': 614,
#    'w': 995,
#    'h': 995,
#    'left_eye': (1606, 988),
#    'right_eye': (1252, 1008)},
#   'img2': {'x': 264,
#    'y': 41,
#    'w': 108,
#    'h': 108,
#    'left_eye': (337, 83),
#    'right_eye': (296, 83)}},
#  'time': 2.18}

# %%
folder_path = "Natalie_Portman"
img1_path = f"{folder_path}/img0.jpg"

folder_path = "Keira_Knightley"
img2_path = f"{folder_path}/img1.jpg"

img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)
graficar(img1[0]["face"],img2[0]["face"])

model_name = "Facenet"
resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp
# Out:
# {'verified': False,
#  'distance': 0.5764522879833742,
#  'threshold': 0.4,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 944,
#    'y': 614,
#    'w': 995,
#    'h': 995,
#    'left_eye': (1606, 988),
#    'right_eye': (1252, 1008)},
#   'img2': {'x': 833,
#    'y': 328,
#    'w': 285,
#    'h': 285,
#    'left_eye': (1026, 433),
#    'right_eye': (913, 435)}},
#  'time': 3.03}

# %%
folder_path = "Natalie_Portman"
img1_path = f"{folder_path}/img0.jpg"

folder_path = "Keira_Knightley"
img2_path = f"{folder_path}/img1.jpg"


for model_name in model_names:
    print(model_name)
    resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
    print(resp)
    print("-"*50)
# Out:
# VGG-Face
# {'verified': True, 'distance': 0.5890496902944304, 'threshold': 0.68, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 2.95}
# --------------------------------------------------
# Facenet
# {'verified': False, 'distance': 0.5764522879833742, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 2.86}
# --------------------------------------------------
# Facenet512
# ...

# %%
img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)
graficar(img1[0]["face"],img2[0]["face"])

# %%
folder_path = "Natalie_Portman"
img1_path = f"{folder_path}/img2.jpg"

folder_path = "Keira_Knightley"
img2_path = f"{folder_path}/img1.jpg"

img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)

fig = plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img1[0]["face"])

plt.subplot(1, 2, 2)
plt.imshow(img2[0]["face"])

model_name = "Facenet"
resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
print(resp)
# Out:
# {'verified': False, 'distance': 0.5505317473787481, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 264, 'y': 41, 'w': 108, 'h': 108, 'left_eye': (337, 83), 'right_eye': (296, 83)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 1.26}

# %%
import pandas as pd

# %%
model_names
# Out:
# ['VGG-Face',
#  'Facenet',
#  'Facenet512',
#  'OpenFace',
#  'DeepID',
#  'ArcFace',
#  'SFace',
#  'GhostFaceNet']

# %%
img_path_source = "Angelina_Jolie/AngelinaJolie1.jpg"
db_path = "Dataset"
resp = DeepFace.find(img_path_source, db_path, model_name = model_names[0])
resp
# Out:
# 25-10-09 14:25:43 - Found 6 newly added image(s), 6 removed image(s), 0 replaced image(s).
# Finding representations: 100%|██████████| 6/6 [00:05<00:00,  1.18it/s]
# 25-10-09 14:25:48 - There are now 6 representations in ds_model_vggface_detector_opencv_aligned_normalization_base_expand_0.pkl
# 25-10-09 14:25:48 - Searching Angelina_Jolie/AngelinaJolie1.jpg in 6 length datastore
# 25-10-09 14:25:49 - find function duration 5.634371042251587 seconds
# [                     identity                                      hash  \
#  0  Dataset/AngelinaJolie2.jpg  d4de5fca4e5b7908d0be01fc70cf5001a37a0e3a
#
#     target_x  target_y  target_w  target_h  source_x  source_y  source_w  \
#  0       416       239       525       525       697       140       505
#
#     source_h  threshold  distance
#  0       505       0.68   0.42752  ,
#                             identity                                      hash  \
# ...

# %%
df = pd.concat(resp, ignore_index=True)
df
# Out:
#                            identity                                      hash  \
# 0        Dataset/AngelinaJolie2.jpg  d4de5fca4e5b7908d0be01fc70cf5001a37a0e3a
# 1  Dataset/Natalie_Portman_img1.jpg  4ddb8cbb8258497c9f4b12b1a5f197bac939d8ef
#
#    target_x  target_y  target_w  target_h  source_x  source_y  source_w  \
# 0       416       239       525       525       697       140       505
# 1       681       323       377       377       802       570       225
#
#    source_h  threshold  distance
# 0       505       0.68  0.427520
# 1       225       0.68  0.543207

# %%
DeepFace.analyze(img_path_source, actions = ['age'])
#DeepFace.analyze(img_path_source)
# Out:
# [{'age': 31,
#   'region': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'face_confidence': 0.92},
#  {'age': 25,
#   'region': {'x': 802,
#    'y': 570,
#    'w': 225,
#    'h': 225,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.96}]

# %%
DeepFace.analyze(img_path_source, actions = ["emotion", "age", "gender", "race"])
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:00<00:00, 12.33it/s]
# [{'emotion': {'angry': 0.18543372862040997,
#    'disgust': 0.0010841647963388823,
#    'fear': 0.40919273160398006,
#    'happy': 46.353548765182495,
#    'sad': 1.4688446186482906,
#    'surprise': 0.2139597199857235,
#    'neutral': 51.36794447898865},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'face_confidence': 0.92,
#   'age': 31,
#   'gender': {'Woman': 99.99996423721313, 'Man': 3.8202020391508995e-05},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 0.014866908326728392,
#    'indian': 0.09205302306580682,
#    'black': 0.0005943644636793301,
#    'white': 84.87293034034552,
#    'middle eastern': 12.846418490792423,
#    'latino hispanic': 2.173137421794976},
#   'dominant_race': 'white'},
#  {'emotion': {'angry': 73.15934300422668,
#    'disgust': 1.85091508786428e-07,
# ...

# %%
embedding_objs = DeepFace.represent(img_path_source)
#embedding_objs

# %%
len(embedding_objs)
# Out:
# 2

# %%
embedding_objs[0].keys(),embedding_objs[1].keys()
# Out:
# (dict_keys(['embedding', 'facial_area', 'face_confidence']),
#  dict_keys(['embedding', 'facial_area', 'face_confidence']))

# %%
embedding_objs[0]["face_confidence"],embedding_objs[1]["face_confidence"]
# Out:
# (0.92, 0.96)

# %%
embedding = embedding_objs[0]["embedding"]
plt.plot(embedding)
plt.title("Embedding Vector")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
DeepFace.stream(db_path = "Dataset")
# Out:
# 25-10-09 14:43:05 - Age model is just built
# 25-10-09 14:43:05 - Gender model is just built
# 25-10-09 14:43:05 - Emotion model is just built
# 25-10-09 14:43:05 - VGG-Face is built
# 2025-10-09 14:43:07.964 python[52954:26848841] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# 25-10-09 14:43:13 - freezed
# 25-10-09 14:43:18 - freeze released
# 25-10-09 14:43:23 - freezed
# 25-10-09 14:43:28 - freeze released
# 25-10-09 14:43:30 - freezed
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %%
folder_path = "Parejas"
img1_path = f"{folder_path}/img0.jpg"
img1 = DeepFace.extract_faces(img1_path)

# %%
len(img1)
# Out:
# 3

# %%
img1[0]["confidence"],img1[1]["confidence"],img1[2]["confidence"]
# Out:
# (0.92, 0.97, 0.91)

# %%
fig = plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img1[1]["face"])

plt.subplot(1, 2, 2)
plt.imshow(img1[2]["face"])

# %%
plt.imshow(img1[0]["face"])

# %%
img_org = plt.imread(img1_path)
plt.imshow(img_org)
